# %% [markdown]
# ## 参考资料
#
# - [10 minutes to pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# - [pandas basics](http://pandas.pydata.org/pandas-docs/stable/basics.html)
# - [tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html)
# - [cookbook and idioms](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)

# %% [markdown]
# ## 如何解决问题
#
# [stackoverflow](www.stackoverflow.com)
#
# [pandas] boolean

# %%
import pandas as pd

# %%
euro12 = pd.read_csv('D:/github/data_analysis/data/Eueo2012.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 选择Goals列

# %%
euro12.set_index('Team',inplace=True)

# %%
euro12.reset_index(inplace=True)

# %%
euro12[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# ### 多少个队参赛?

# %%
euro12.shape
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# ### 有多少列数据?

# %%
euro12.shape[1]
# Out:
# 34

# %% [markdown]
# ### 仅察看Team, Yellow Cards,Red Cards列,将结果赋值给一个变量

# %%
check_euro12 = euro12[['Team','Yellow Cards','Red Cards']]
check_euro12
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### 根据Red Cards,以及 Yellow Cards对数据排序

# %%
check_euro12.sort_values(['Red Cards','Yellow Cards'],ascending=True)
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# ### 平均每个队得了几张Yellow Cards

# %%
check_euro12[['Yellow Cards']].mean()
# Out:
# Yellow Cards    7.4375
# dtype: float64

# %% [markdown]
# ### 选取进球多于6个的队

# %%
euro12[['Goals']]>6
euro12[euro12.Goals>6]['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### 选择地6,7只队

# %%
euro12.iloc[[6,7]]
# Out:
#      Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 6  Greece      5                8                18             30.7%
# 7   Italy      6               34                45             43.0%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 6            19.2%                          32             1              1
# 7             7.5%                         110             2              0
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 6                     1      ...               13                 65.1%
# 7                     0      ...               20                 74.1%
#
#    Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 6         67             48        12             9          1       12
# 7        101             89        16            16          0       18
#
#    Subs off  Players Used
# 6        12            20
# 7        18            19
#
# ...

# %% [markdown]
# ### 选择前面6列

# %%
euro12.loc[:6]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# ### 选择除最后3列以外的所有列

# %%
euro12.iloc[:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
#
# ...

# %% [markdown]
# ### 显示England, Italy Russia的Shooting Accuracy

# %%
euro12_cp = euro12.copy()
euro12_cp
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12_cp
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro12_cp.loc[['England','Italy','Russia']][['Shooting Accuracy']]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %%
euro12_cp.loc[['England','Italy']]
# Out:
#          Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# England      5               11                18             50.0%
# Italy        6               34                45             43.0%
#
#         % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# England            17.2%                          40             0
# Italy               7.5%                         110             2
#
#          Penalty goals  Penalties not scored  Headed goals      ...       \
# Team                                                            ...
# England              0                     0             3      ...
# Italy                0                     0             2      ...
#
#          Saves made  Saves-to-shots ratio Fouls Won  Fouls Conceded  Offsides  \
# Team
# England          22                 88.1%        43              45         6
# Italy            20                 74.1%       101              89        16
#
# ...
